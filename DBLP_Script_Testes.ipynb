# %% [markdown]
# ## Coletando informações sobre artigos direto da API pública da DBLP
#
# > REF.: https://dblp.uni-trier.de/

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
import dblp

# %%
# Informe nessa variável o caminho para salvar os seus arquivos ".csv"
dblp.path_to_save = "xxxxx/"

# %%
df = dblp.dblp2dataframe('person name disambiguation')
df
# Out:
#     year  dblp_id                                              title  \
# 5   2018   217719  A Survey of Person Name Disambiguation on the ...
# 6   2018   233519  Web Person Name Disambiguation Using Social Li...
# 7   2018   277820  Person name disambiguation on the web in a mul...
# 9   2017   814292  LSI UNED at M-WePNaD - Embeddings for Person N...
# 10  2017   814306  Overview of the M-WePNaD Task - Multilingual W...
# 8   2017   616992  Person Name Disambiguation in the Web Using Ad...
# 14  2016  1095644  You Shall Know People by the Company They Keep...
# 13  2016   993449  Person Name Disambiguation for Building Univer...
# 11  2016   908475  Incorporating multi-kernel function and Intern...
# 12  2016   931223  Chinese Person Name Disambiguation Based on Tw...
# 15  2015  1389430  Online Person Name Disambiguation with Constra...
# 16  2015  1400108  Personalized Page Rank for Named Entity Disamb...
# 17  2014  1538014  An Unsupervised Algorithm for Person Name Disa...
# ...

# %%
top_authors_freq = dblp.get_top_authors_freq(df,top=20)
top_authors_freq
# Out:
# [('Soto Montalvo', 6),
#  ('Agustín D. Delgado', 5),
#  ('Raquel Martínez-Unanue 0001', 4),
#  ('Víctor Fresno', 4),
#  ('Ying Chen', 3),
#  ('James H. Martin', 3),
#  ('Víctor Fresno-Fernández', 2),
#  ('Raquel Martínez 0001', 2),
#  ('Ruifeng Xu', 2),
#  ('Qin Lu', 2),
#  ('Zhao Lu', 2),
#  ('Peng Jin', 2),
#  ('Wenjie Li', 2),
#  ('Elena Smirnova', 2),
#  ('Konstantin Avrachenkov', 2),
#  ('Minoru Yoshida', 2),
#  ('Shingo Ono', 2),
#  ('Issei Sato', 2),
#  ('Hiroshi Nakagawa', 2),
#  ('Chen Chen', 2)]

# %%
dblp.plot_top_authors(df, top=10)

# %%
authors_top_frequency = dblp.get_top_authors(df,5)
for author in authors_top_frequency:
    print(author)
# Out:
# Soto Montalvo
# Agustín D. Delgado
# Raquel Martínez-Unanue 0001
# Víctor Fresno
# Ying Chen

# %%
print( dblp.path_to_save)
# Out:
# xxxxx/

# %%
dblp.df2csv("testanto2.csv",df)

# %%
dblp.get_papers_and_csv_save(['person name disambiguation','author name disambiguation'])
# Out:
# 	 person name disambiguation =>  55 saved...
# 	 author name disambiguation =>  97 saved...
# Total:  152

# %%
dblp.get_top_authors_freq(df)
# Out:
# [('Soto Montalvo', 6),
#  ('Agustín D. Delgado', 5),
#  ('Raquel Martínez-Unanue 0001', 4),
#  ('Víctor Fresno', 4),
#  ('Ying Chen', 3),
#  ('James H. Martin', 3),
#  ('Víctor Fresno-Fernández', 2),
#  ('Raquel Martínez 0001', 2),
#  ('Ruifeng Xu', 2),
#  ('Qin Lu', 2),
#  ('Zhao Lu', 2),
#  ('Peng Jin', 2),
#  ('Wenjie Li', 2),
#  ('Elena Smirnova', 2),
#  ('Konstantin Avrachenkov', 2),
#  ('Minoru Yoshida', 2),
#  ('Shingo Ono', 2),
#  ('Issei Sato', 2),
#  ('Hiroshi Nakagawa', 2),
#  ('Chen Chen', 2),
#  ('Houfeng Wang', 2),
#  ('Ying Chen 0012', 2),
#  ('Chu-Ren Huang', 2),
#  ('Rohini K. Srihari', 2),
#  ('Quang Minh Vu', 2),
#  ('Atsuhiro Takasu', 2),
#  ('Jun Adachi', 2),
#  ('David Yarowsky', 2),
#  ('Hojjat Emami', 1),
#  ('Hossein Shirazi', 1),
#  ('Ahmad Abdollahzadeh Barforoush', 1),
#  ('Andres Duque Fernandez', 1),
#  ('Lourdes Araujo', 1),
#  ('Juan Martinez-Romo', 1),
#  ('Agustín Daniel Delgado', 1),
#  ('Arkaitz Zubiaga', 1),
#  ('Richard Berendsen', 1),
# ...
